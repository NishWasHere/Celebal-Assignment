# %% [markdown]
# <a href="https://colab.research.google.com/github/NishWasHere/Celebal-Assignment/blob/main/TitanicVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset (Kaggle dataset or seaborn's built-in Titanic dataset)
df = sns.load_dataset('titanic')  # easier to run directly

# %%
print(df.head())
print(df.info())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
sns.countplot(x='survived', data=df)
plt.title('Survival Count (0 = No, 1 = Yes)')
plt.show()

# %% [markdown]
# Survival Count

# %% [markdown]
# Survival by gender

# %%
sns.countplot(x='sex', hue='survived', data=df)
plt.title('Survival by Gender')
plt.show()

# %% [markdown]
# Class-wise Survival

# %%
sns.countplot(x='class', hue='survived', data=df)
plt.title('Survival by Passenger Class')
plt.show()

# %% [markdown]
# Age Distribution

# %%
sns.histplot(df['age'].dropna(), bins=30, kde=True)
plt.title('Age Distribution of Passengers')
plt.show()

# %% [markdown]
# Fare Distribution

# %%
sns.boxplot(x='class', y='fare', data=df)
plt.title('Fare Distribution by Class')
plt.show()

# %% [markdown]
# Survival of Children vs Adults

# %%
df['is_child'] = df['age'].apply(lambda x: 'Child' if x < 16 else 'Adult')
sns.countplot(x='is_child', hue='survived', data=df)
plt.title('Survival of Children vs Adults')
plt.show()
